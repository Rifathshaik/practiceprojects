# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("crimes_against_women_2001_2012.csv")

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
df.shape
# Out:
# (9017, 10)

# %% [markdown]
# CHECKING FOR NULLS

# %%
df.isnull().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping and Abduction                               0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %% [markdown]
# there are no null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9017 non-null   object
#  1   DISTRICT                                             9017 non-null   object
#  2   Year                                                 9017 non-null   int64
#  3   Rape                                                 9017 non-null   int64
#  4   Kidnapping and Abduction                             9017 non-null   int64
#  5   Dowry Deaths                                         9017 non-null   int64
#  6   Assault on women with intent to outrage her modesty  9017 non-null   int64
#  7   Insult to modesty of Women                           9017 non-null   int64
# ...

# %%
df['STATE/UT'].nunique()
# Out:
# 35

# %%
df['STATE/UT'].value_counts()
# Out:
# UTTAR PRADESH        878
# MADHYA PRADESH       628
# MAHARASHTRA          552
# BIHAR                540
# TAMIL NADU           469
# RAJASTHAN            454
# ODISHA               430
# KARNATAKA            399
# GUJARAT              384
# ANDHRA PRADESH       370
# ASSAM                362
# JAMMU & KASHMIR      322
# PUNJAB               314
# JHARKHAND            312
# WEST BENGAL          309
# HARYANA              268
# CHHATTISGARH         266
# KERALA               233
# ARUNACHAL PRADESH    195
# DELHI                183
# HIMACHAL PRADESH     176
# UTTARAKHAND          168
# NAGALAND             138
# MANIPUR              125
# MIZORAM              108
# MEGHALAYA             96
# TRIPURA               67
# SIKKIM                60
# A & N ISLANDS         36
# DAMAN & DIU           36
# GOA                   36
# PUDUCHERRY            31
# D & N HAVELI          24
# LAKSHADWEEP           24
# CHANDIGARH            24
# Name: STATE/UT, dtype: int64

# %% [markdown]
# OBSERVATION::
#
#         UP,MADHYA PRADESH & MAHARASHTRA occupies top 3 places in no.of crimes against women
#
#         D&Nhaveli,LAKSHDWEEP,CHANDIGARH has least no.of crimes against women compared to rest of the states.

# %% [markdown]
# Crimes against women are recorded under 7 cateogeries:
#
#     1) Rape
#     2) Kidnapping and Abduction
#     3)Dowry Deaths
#     4) Assault on women with intent to outrage her modesty
#     5)Insult to modesty of Women
#     6)Cruelty by Husband or his Relatives
#     7)Importation of Girls
#
#  Both 5 and 4 columns appear to be same hence merging them into one column

# %%
df['Insult to modesty of Women']=df['Assault on women with intent to outrage her modesty']+df['Insult to modesty of Women']

# %%
df.drop(['Assault on women with intent to outrage her modesty'],axis=1,inplace=True)

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Insult to modesty of Women  \
# 0            16                         183
# 1             7                         142
# 2            14                         195
# 3            17                         164
# 4            12                         167
#
#    Cruelty by Husband or his Relatives  Importation of Girls
# 0                                  175                     0
# 1                                  154                     0
# 2                                  186                     0
# ...

# %% [markdown]
# # state wise summation of respective crimes

# %%
df_statewise=df.groupby('STATE/UT')[['Rape','Kidnapping and Abduction','Dowry Deaths','Insult to modesty of Women','Cruelty by Husband or his Relatives','Importation of Girls']].sum()

# %%
df_statewise
# Out:
#                     Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# A & N ISLANDS        218                       154            12
# ANDHRA PRADESH     26958                     29872         12430
# ARUNACHAL PRADESH   1000                      1116             4
# ASSAM              32356                     45840          2552
# BIHAR              26248                     38778         27096
# CHANDIGARH           562                      1068            84
# CHHATTISGARH       23676                      5260          2284
# D & N HAVELI         112                       188             2
# DAMAN & DIU           40                        30             6
# DELHI              12848                     31300          3164
# GOA                  700                       328            38
# GUJARAT             8498                     25836          1004
# HARYANA            12820                     12258          6260
# ...

# %% [markdown]
# # TOTAL NO.OF CASES  YEAR WISE BASED ON OFFENCE

# %%
df_rape_byyear=df.groupby('Year')['Rape'].sum()
#converting series to dataframe
#df_rape_byyear=pd.DataFrame(df_rape_byyear)
df_rape={'Year':[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],
                'Rape':[32150,32746,31694,36466,36718,38696,41474,42934,42794,44344,48412,49846]
    
}

# %%
df_KidnapbyYear=df.groupby('Year')['Kidnapping and Abduction'].sum()

df_Kidnap={'Year':[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],
           'KidnapAbduction':[29290,29012,26592,31156,31500,34828,40832,45878,51482,59590,71130,76524]
    
}

# %%
df_DowryByYear=df.groupby('Year')['Dowry Deaths'].sum()

print("From 2001 to 2014 Total No.of Dowry Deaths\n ",df_DowryByYear)
df_dowryDeath={'Year':[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],
               
    'Dowry Deaths':[13702,13644,12416,14052,13574,15236,16186,16344,16766,16782,17236,16466]
}
# Out:
# From 2001 to 2014 Total No.of Dowry Deaths
#   Year
# 2001    13702
# 2002    13644
# 2003    12416
# 2004    14052
# 2005    13574
# 2006    15236
# 2007    16186
# 2008    16344
# 2009    16766
# 2010    16782
# 2011    17236
# 2012    16466
# Name: Dowry Deaths, dtype: int64

# %%
df_InsltModstByYear=df.groupby('Year')['Insult to modesty of Women'].sum()

print("From 2001 to 2014 Total No.of Insult to modesty of Women: \n",df_InsltModstByYear)
df_InsultModesty={ 'Year':[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],
                  'Insult':[87740,88196,90528,89136,88318,93166,99368,105254,99440,101148,103076,109048]
    
}
# Out:
# From 2001 to 2014 Total No.of Insult to modesty of Women:
#  Year
# 2001     87740
# 2002     88196
# 2003     90528
# 2004     89136
# 2005     88318
# 2006     93166
# 2007     99368
# 2008    105254
# 2009     99440
# 2010    101148
# 2011    103076
# 2012    109048
# Name: Insult to modesty of Women, dtype: int64

# %%
df_HusRelcrlty_Year=df.groupby('Year')['Cruelty by Husband or his Relatives'].sum()
print("From 2001 to 2014 Total No.of Cruelty by Husband or his Relatives::\n",df_HusRelcrlty_Year)
df_crueltyInlaws={ 'Year':[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],
                   'Cruelty':[98340,98474,101406,116242,116638,126256,151860,162688,179092,188082,198270,213054]
    
}
# Out:
# From 2001 to 2014 Total No.of Cruelty by Husband or his Relatives::
#  Year
# 2001     98340
# 2002     98474
# 2003    101406
# 2004    116242
# 2005    116638
# 2006    126256
# 2007    151860
# 2008    162688
# 2009    179092
# 2010    188082
# 2011    198270
# 2012    213054
# Name: Cruelty by Husband or his Relatives, dtype: int64

# %%
df_ImportGirls_Year=df.groupby('Year')['Importation of Girls'].sum()
print("From 2001 to 2014 Total No.of Importation of Girls::\n ",df_ImportGirls_Year)
df_ImportGirls={'Year':[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],
                'Import':[228,152,92,178,298,134,122,134,96,72,160,118]
    
}
# Out:
# From 2001 to 2014 Total No.of Importation of Girls::
#   Year
# 2001    228
# 2002    152
# 2003     92
# 2004    178
# 2005    298
# 2006    134
# 2007    122
# 2008    134
# 2009     96
# 2010     72
# 2011    160
# 2012    118
# Name: Importation of Girls, dtype: int64

# %% [markdown]
# # Pictorial Representation of  types of offences Year wise

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.barplot(x=df_rape['Year'],y=df_rape['Rape'])
plt.title('Rape Cases Over Years 2001-2012')
# Out:
# Text(0.5, 1.0, 'Rape Cases Over Years 2001-2012')

# %%
sns.barplot(x=df_Kidnap['Year'],y=df_Kidnap['KidnapAbduction'])
plt.title("Kidnapping and Abduction Over Years 2001-2012")
# Out:
# Text(0.5, 1.0, 'Kidnapping and Abduction Over Years 2001-2012')

# %%
sns.barplot(x=df_dowryDeath['Year'],y=df_dowryDeath['Dowry Deaths'])
plt.title("Dowry Deaths Over Years 2001-2012")
# Out:
# Text(0.5, 1.0, 'Dowry Deaths Over Years 2001-2012')

# %%
sns.barplot(x=df_InsultModesty['Year'],y=df_InsultModesty['Insult'])
plt.title("Insult to modesty of Women Over Years 2001-2012")
# Out:
# Text(0.5, 1.0, 'Insult to modesty of Women Over Years 2001-2012')

# %%
sns.barplot(x=df_crueltyInlaws['Year'],y=df_crueltyInlaws['Cruelty'])
plt.title("Cruelty by Husband or his Relatives Over Years 2001-2012")
# Out:
# Text(0.5, 1.0, 'Cruelty by Husband or his Relatives Over Years 2001-2012')

# %%
sns.barplot(x=df_ImportGirls['Year'],y=df_ImportGirls['Import'])
plt.title("Importation of Girls Over Years 2001-2012")
# Out:
# Text(0.5, 1.0, 'Importation of Girls Over Years 2001-2012')

# %% [markdown]
# # SUMMARY:
#
#     Rape,Kidnap and abduction cruelty by husband and in laws kept increasing every year from 2001 to 2012
#
#     Dowry death were at peaks in 2011 then reduced by a bit in 2012
#
#     Insult to modesty was higher in 2008 then reduced in 2009 and steady increased till 2012
#
#     Importation of girls was higher in 2005 then comparitively decreased by 2012

# %% [markdown]
# # RAPE CASES STATE WISE

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=df['Rape'],y=df['STATE/UT'])

# %% [markdown]
# # SUMMARY:
#
#
#     West Bengal has highest rape cases followed by madhya pradesh,chattisgharh,assam,AndhraPradesh

# %% [markdown]
# # Kidnapping and Abduction state Wise

# %%
plt.figure(figsize=(20,20))
sns.barplot(y=df['STATE/UT'],x=df['Kidnapping and Abduction'])

# %% [markdown]
# Summary:
#
#     Top states in kidnapping and abduction of women:
#         1)Delhi
#         2)west bengal
#         3)Assam

# %% [markdown]
# # Dowry Deaths State wise

# %%
plt.figure(figsize=(20,20))
sns.barplot(y=df['STATE/UT'],x=df['Dowry Deaths'])

# %% [markdown]
# Top states in dowry deaths:
#
#     1)Uttar pradesh
#
#     2)Bihar
#
#     3)Andhra Pradesh

# %% [markdown]
# # Insult to modesty of Women State wise

# %%
plt.figure(figsize=(20,20))
sns.barplot(y=df['STATE/UT'],x=df['Insult to modesty of Women'])

# %% [markdown]
# top states in Insult to modesty of women:
#
#     1)AndhraPradesh
#
#     2)Kerala
#
#     3)Madhya Pradesh

# %% [markdown]
# # Cruelty by Husband or his Relatives state wise

# %%
plt.figure(figsize=(20,20))
sns.barplot(y=df['STATE/UT'],x=df['Cruelty by Husband or his Relatives'])

# %% [markdown]
# TOP STATES::
#
#         1)West Bengal
#
#         2)Andhra Pradesh
#
#         3)Rajasthan

# %% [markdown]
# # Importation of Girls state wise

# %%
plt.figure(figsize=(20,20))
sns.barplot(y=df['STATE/UT'],x=df['Importation of Girls'])

# %% [markdown]
# TOP STATES::
#
#         1)Bihar
#
#         2)Jarkhand
#
#         3)WestBengal

# %%
df_statewise['Rape'].sort_values(ascending=True).head(5)
# Out:
# STATE/UT
# LAKSHADWEEP       14
# DAMAN & DIU       40
# D & N HAVELI     112
# PUDUCHERRY       154
# A & N ISLANDS    218
# Name: Rape, dtype: int64

# %% [markdown]
# # STATES WITH LOWEST RAPE CASES:
#
#     1) LAKSHADWEEP  with 14 cases
#     2)DAMAN & DIU   with 40 cases
#     3)D & N HAVELI  with 112 cases
#     4)PUDUCHERRY    with 154 cases

# %% [markdown]
# # States With lowest Kidnapping and Abduction

# %%
df_statewise['Kidnapping and Abduction'].sort_values(ascending=True).head(5)
# Out:
# STATE/UT
# LAKSHADWEEP      2
# MIZORAM         20
# DAMAN & DIU     30
# SIKKIM         124
# NAGALAND       142
# Name: Kidnapping and Abduction, dtype: int64

# %% [markdown]
# # States with lowest Dowry Deaths

# %%
df_statewise['Dowry Deaths'].sort_values(ascending=True).head(5)
# Out:
# STATE/UT
# NAGALAND             0
# LAKSHADWEEP          0
# D & N HAVELI         2
# SIKKIM               4
# ARUNACHAL PRADESH    4
# Name: Dowry Deaths, dtype: int64

# %% [markdown]
# # states with lowest Insult to modesty of Women

# %%
df_statewise['Insult to modesty of Women'].sort_values(ascending=True).head(5)
# Out:
# STATE/UT
# LAKSHADWEEP      10
# DAMAN & DIU      34
# D & N HAVELI    108
# NAGALAND        212
# SIKKIM          488
# Name: Insult to modesty of Women, dtype: int64

# %% [markdown]
# # states with lowest Cruelty by Husband or his Relatives

# %%
df_statewise['Cruelty by Husband or his Relatives'].sort_values(ascending=True).head(5)
# Out:
# STATE/UT
# LAKSHADWEEP     14
# NAGALAND        18
# DAMAN & DIU     70
# D & N HAVELI    76
# SIKKIM          88
# Name: Cruelty by Husband or his Relatives, dtype: int64

# %% [markdown]
# # states with lowest Importation of Girls

# %%
df_statewise['Importation of Girls'].sort_values(ascending=True).head(5)
# Out:
# STATE/UT
# A & N ISLANDS    0
# TRIPURA          0
# SIKKIM           0
# PUDUCHERRY       0
# MANIPUR          0
# Name: Importation of Girls, dtype: int64

# %% [markdown]
# # SUMMARY:
#     Safest places overall in india with lower crime rates:
#         1)LAKSHADWEEP
#         2)NAGALAND
#         3)DAMAN & DIU
#         4)D & N HAVELI
#         5)SIKKIM
#         6)A & N ISLANDS
#         7)TRIPURA
#         8)PUDUCHERRY
#         6)MANIPUR
