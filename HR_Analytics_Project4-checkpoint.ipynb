# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Columns of object data type:

# %%
object_dtypes=df.select_dtypes(exclude=['int64'])
object_dtypes.columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %% [markdown]
# OBSERVATION::
#
#         Out of 35 columns 9 columns are of object datatype

# %%
#finding Attrition-columns unique values and their counts

print("No.of Unique entries in attrition columns:",df['Attrition'].nunique())

print("\n their corresponding values:\n",df['Attrition'].value_counts())
# Out:
# No.of Unique entries in attrition columns: 2
#
#  their corresponding values:
#  No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#finding BusinessTravel-columns unique values and their counts

print("No.of Unique entries in BusinessTravel columns:",df['BusinessTravel'].nunique())

print("\n their corresponding values:\n",df['BusinessTravel'].value_counts())
# Out:
# No.of Unique entries in BusinessTravel columns: 3
#
#  their corresponding values:
#  Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
#finding Department-columns unique values and their counts

print("No.of Unique entries in Department columns:",df['Department'].nunique())

print("\n their corresponding values:\n",df['Department'].value_counts())
# Out:
# No.of Unique entries in Department columns: 3
#
#  their corresponding values:
#  Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
#finding EducationField-columns unique values and their counts

print("No.of Unique entries in EducationField columns:",df['EducationField'].nunique())

print("\n their corresponding values:\n",df['EducationField'].value_counts())
# Out:
# No.of Unique entries in EducationField columns: 6
#
#  their corresponding values:
#  Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#finding Gender-columns unique values and their counts

print("No.of Unique entries in Gender columns:",df['Gender'].nunique())

print("\n their corresponding values:\n",df['Gender'].value_counts())
# Out:
# No.of Unique entries in Gender columns: 2
#
#  their corresponding values:
#  Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
#finding JobRole-columns unique values and their counts

print("No.of Unique entries in JobRole columns:",df['JobRole'].nunique())

print("\n their corresponding values:\n",df['JobRole'].value_counts())
# Out:
# No.of Unique entries in JobRole columns: 9
#
#  their corresponding values:
#  Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
#finding MaritalStatus-columns unique values and their counts

print("No.of Unique entries in MaritalStatus columns:",df['MaritalStatus'].nunique())

print("\n their corresponding values:\n",df['MaritalStatus'].value_counts())
# Out:
# No.of Unique entries in MaritalStatus columns: 3
#
#  their corresponding values:
#  Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
#finding Over18-columns unique values and their counts

print("No.of Unique entries in Over18 columns:",df['Over18'].nunique())

print("\n their corresponding values:\n",df['Over18'].value_counts())
# Out:
# No.of Unique entries in Over18 columns: 1
#
#  their corresponding values:
#  Y    1470
# Name: Over18, dtype: int64

# %% [markdown]
# OBSERVATION:
#
#     AS there is only one entry and all the employees are over 18,this column wont have significant effect on attrition.
#
#     Hence,Dropping this column

# %%
df.drop(['Over18'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1470, 34)

# %%
#finding OverTime-columns unique values and their counts

print("No.of Unique entries in OverTime columns:",df['OverTime'].nunique())

print("\n their corresponding values:\n",df['OverTime'].value_counts())
# Out:
# No.of Unique entries in OverTime columns: 2
#
#  their corresponding values:
#  No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# # Summary of object type columns::
#
#     Department wise Ranking Based on no.of employees working in it:
#
#         1)Research & Development with  961 employees
#
#         2)Sales with  446 employees
#
#         3)Human Resources  with  63 employees
#
#     Education wise count of employees:
#
#         1) Life Sciences       606
#
#         2) Medical             464
#
#         3)Marketing           159
#
#         4)Technical Degree    132
#
#         5)Other                82
#
#         6)Human Resources      27
#
#
#     Designation wise count of employees:
#
#         1)Sales Executive              326
#
#         2)Research Scientist           292
#
#         3)Laboratory Technician        259
#
#         4)Manufacturing Director       145
#
#         5)Healthcare Representative    131
#
#         6)Manager                      102
#
#         7)Sales Representative          83
#
#         8)Research Director             80
#
#         9)Human Resources               52
#
#
#
# Majority of the employees are married and there are significantly higher no.of males[33%] compared to females

# %% [markdown]
# # COLUMNS OF NUMERIC TYPE:

# %%
Numeric_types=df.select_dtypes(include=['int64'])
Numeric_types.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# Observation:
#
#     There are 26 numeric columns in this dataset.
#
#     1)As education field is already present Education column doesnt make sense,hence dropping it.
#     2)As employee number doesnt affect attrition rate,dropping it.

# %%
df.drop(['Education'],axis=1,inplace=True)
df.drop(['EmployeeNumber'],axis=1,inplace=True)

# %%
#finding Age-columns unique values and their counts
print("No.of Unique entries in Age columns:",df['Age'].nunique())
# Out:
# No.of Unique entries in Age columns: 43

# %%
#finding YearsAtCompany-columns unique values and their counts
print("No.of Unique entries in YearsAtCompany columns:",df['YearsAtCompany'].nunique())
# Out:
# No.of Unique entries in YearsAtCompany columns: 37

# %%
print("No.of Unique entries in MonthlyIncome columns:",df['MonthlyIncome'].nunique())
# Out:
# No.of Unique entries in MonthlyIncome columns: 1349

# %%
print("No.of Unique entries in JobLevel columns:",df['JobLevel'].nunique())
# Out:
# No.of Unique entries in JobLevel columns: 5

# %%
print("No.of Unique entries in DailyRate columns:",df['DailyRate'].nunique())
# Out:
# No.of Unique entries in DailyRate columns: 886

# %%
print("No.of Unique entries in EmployeeCount columns:",df['EmployeeCount'].nunique())
# Out:
# No.of Unique entries in EmployeeCount columns: 1

# %%
print("No.of values in EmployeeCount columns:",df['EmployeeCount'].value_counts())
# Out:
# No.of values in EmployeeCount columns: 1    1470
# Name: EmployeeCount, dtype: int64

# %% [markdown]
# Observation:
#     As there is only 1 value in EmployeeCount column,dropping it.

# %%
df.drop(['EmployeeCount'],axis=1,inplace=True)

# %%
print("\nNo.of values in DistanceFromHome columns:",df['DistanceFromHome'].nunique())
print("\nNo.of values in EnvironmentSatisfaction columns:",df['EnvironmentSatisfaction'].nunique())
print("\nNo.of values in HourlyRate columns:",df['HourlyRate'].nunique())
print("\nNo.of values in JobInvolvement columns:",df['JobInvolvement'].nunique())
print("\nNo.of values in JobSatisfaction columns:",df['JobSatisfaction'].nunique())
print("\nNo.of values in MonthlyRate columns:",df['MonthlyRate'].nunique())
print("\nNo.of values in NumCompaniesWorked columns:",df['NumCompaniesWorked'].nunique())
print("\nNo.of values in PercentSalaryHike columns:",df['PercentSalaryHike'].nunique())
print("\nNo.of values in PerformanceRating columns:",df['PerformanceRating'].nunique())
print("\nNo.of values in RelationshipSatisfaction columns:",df['RelationshipSatisfaction'].nunique())
print("\nNo.of values in StandardHours columns:",df['StandardHours'].nunique())
print("\nNo.of values in StockOptionLevel columns:",df['StockOptionLevel'].nunique())
print("\nNo.of values in TotalWorkingYears columns:",df['TotalWorkingYears'].nunique())
print("\nNo.of values in TrainingTimesLastYear columns:",df['TrainingTimesLastYear'].nunique())
print("\nNo.of values in WorkLifeBalance columns:",df['WorkLifeBalance'].nunique())
print("\nNo.of values in YearsInCurrentRole columns:",df['YearsInCurrentRole'].nunique())
print("\nNo.of values in YearsSinceLastPromotion columns:",df['YearsSinceLastPromotion'].nunique())
print("\nNo.of values in YearsWithCurrManager columns:",df['YearsWithCurrManager'].nunique())
# Out:
# No.of values in DistanceFromHome columns: 29
#
# No.of values in EnvironmentSatisfaction columns: 4
#
# No.of values in HourlyRate columns: 71
#
# No.of values in JobInvolvement columns: 4
#
# No.of values in JobSatisfaction columns: 4
#
# No.of values in MonthlyRate columns: 1427
#
# No.of values in NumCompaniesWorked columns: 10
#
# No.of values in PercentSalaryHike columns: 15
#
# No.of values in PerformanceRating columns: 2
#
# No.of values in RelationshipSatisfaction columns: 4
#
# No.of values in StandardHours columns: 1
#
# No.of values in StockOptionLevel columns: 4
#
# No.of values in TotalWorkingYears columns: 40
#
# No.of values in TrainingTimesLastYear columns: 7
#
# No.of values in WorkLifeBalance columns: 4
#
# No.of values in YearsInCurrentRole columns: 19
#
# No.of values in YearsSinceLastPromotion columns: 16
#
# No.of values in YearsWithCurrManager columns: 18

# %% [markdown]
# Observation:
#
#     There is only 1 value in standard hours columns,hence deleting it.

# %%
print("No.of values in StandardHours  columns:",df['StandardHours'].value_counts())
# Out:
# No.of values in StandardHours  columns: 80    1470
# Name: StandardHours, dtype: int64

# %%
df.drop(['StandardHours'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1470, 30)

# %% [markdown]
# # data visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.countplot(x = 'Attrition',
              hue='Gender',
              data = df,
              palette="YlOrRd_r")

# %% [markdown]
# OBSERVATION::
#
#         1.overall Attrition is less.
#
#         2.Attrition is higher in males compared to females

# %%
sns.barplot(x=df['Attrition'],y=df['YearsAtCompany'],hue=df['Department'])
plt.title('Attrition levels compared to years at company')
# Out:
# Text(0.5, 1.0, 'Attrition levels compared to years at company')

# %% [markdown]
# Attrition present at employees with less years at the company
#
# attrition is greater in sales department compared to rest

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=df['Attrition'],y=df['MonthlyIncome'],hue=df['JobRole'])
plt.title('Attrition levels compared to years at company')
# Out:
# Text(0.5, 1.0, 'Attrition levels compared to years at company')

# %% [markdown]
# Attrition levels higher in higher income roles like
#
#  1)Reasearch directoe
#
#  2)Manager
#
#  3)Health care Representative
#
# Attrition levels lesser in less income roles like:
#
#     1)Sales Representative
#
#     2)Research scientist
#
#     3)Laboratory Technician

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=df['Attrition'],y=df['TotalWorkingYears'],hue=df['BusinessTravel'])

# %% [markdown]
# Attrition is present in employees of experience less than 10 years.
#
# and is higher in rare travel group followed by non travel and frequently travelling group of employees

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=df['Attrition'],y=df['PerformanceRating'],hue=df['JobRole'])

# %% [markdown]
# # attrition rate higher in higher rating and in research scientists and labtechnicians who record high performance

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=df['Attrition'],y=df['WorkLifeBalance'],hue=df['MaritalStatus'])

# %% [markdown]
# Attrition rate higher in married people compared to single and divorced

# %%
sns.barplot(x=df['OverTime'],y=df['YearsInCurrentRole'])

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'EducationField', 'EnvironmentSatisfaction',
#        'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # CHECKING FOR SKEWNESS

# %%
df.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# skewness is present in all columns

# %% [markdown]
# # Converting Object columns to numeric through Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Attrition']=le.fit_transform(df['Attrition'])
df['BusinessTravel']=le.fit_transform(df['BusinessTravel'])
df['Department']=le.fit_transform(df['Department'])
df['EducationField']=le.fit_transform(df['EducationField'])
df['Gender']=le.fit_transform(df['Gender'])
df['JobRole']=le.fit_transform(df['JobRole'])
df['MaritalStatus']=le.fit_transform(df['MaritalStatus'])
df['OverTime']=le.fit_transform(df['OverTime'])

# %% [markdown]
# # Checking for correlation

# %%
df_Cor=df.corr()

# %%
df_Cor
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# JobInvolvement            0.029820  -0.130016        0.039062   0.046135
# JobLevel                  0.509604  -0.169105        0.019311   0.002966
# ...

# %% [markdown]
# # Plotting correlations through heat map

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(20,20))
sns.heatmap(df_Cor,cmap='Blues',annot=True)

# %%
#checking correlation with target column

df_Cor['Attrition'].sort_values(ascending=False)
# Out:
# Attrition                   1.000000
# OverTime                    0.246118
# MaritalStatus               0.162070
# DistanceFromHome            0.077924
# JobRole                     0.067151
# Department                  0.063991
# NumCompaniesWorked          0.043494
# Gender                      0.029453
# EducationField              0.026846
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# BusinessTravel              0.000074
# HourlyRate                 -0.006846
# PercentSalaryHike          -0.013478
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# StockOptionLevel           -0.137145
# YearsWithCurrManager       -0.156199
# ...

# %% [markdown]
# Highly positive correlated columns:
#
#     1)Overtime
#
#     2)Marital status

# %% [markdown]
# # outlier removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
print(z)
threshold=3
print(np.where(z>threshold))
# Out:
# [[0.4463504  2.28090588 0.59004834 ... 0.0632959  0.67914568 0.24583399]
#  [1.32236521 0.4384223  0.91319439 ... 0.76499762 0.36871529 0.80654148]
#  [0.008343   2.28090588 0.59004834 ... 1.16768726 0.67914568 1.15593471]
#  ...
#  [1.08667552 0.4384223  0.59004834 ... 0.61549158 0.67914568 0.31487349]
#  [1.32236521 0.4384223  0.91319439 ... 0.48889978 0.67914568 1.08689522]
#  [0.32016256 0.4384223  0.59004834 ... 0.33939374 0.36871529 0.59522723]]
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
# ...

# %%
#removing outliers

df1=df[(z<3).all(axis=1)]

print("With out removing outliers::",df.shape)
print("After removing outliers::",df1.shape)
# Out:
# With out removing outliers:: (1470, 30)
# After removing outliers:: (1387, 30)

# %% [markdown]
# Observation::
#
#         Only 5% of data is removed by outliers.

# %%
x=df1.drop(['Attrition'],axis=1)
x.shape
# Out:
# (1387, 29)

# %%
y=df1['Attrition']
y.shape
# Out:
# (1387,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (1387, 1)

# %% [markdown]
# # Skewness Removal

# %%
from sklearn.preprocessing import power_transform

x=power_transform(df1,method='yeo-johnson')
# Out:
# C:\ANACONDA\lib\site-packages\sklearn\preprocessing\_data.py:3234: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# # Checking for best random sate with highest accuracy for different models

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')

# %%
best_Randstate=0
accuracy=0
model=[LogisticRegression(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]
for m in model:
            for i in range(20,100):
                                    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=i)
                                    m.fit(x_train,y_train)
                                    predicted_y=m.predict(x_test)
                                    accu_temp=accuracy_score(y_test,predicted_y)
                                    if(accu_temp>accuracy):
                                                accuracy=accu_temp
                                                best_Randstate=i
            print("Acuuracy of ",accuracy*100,"for Model::",m,"found in Random state:",best_Randstate)
# Out:
# Acuuracy of  100.0 for Model:: LogisticRegression() found in Random state: 20
# Acuuracy of  100.0 for Model:: SVC() found in Random state: 20
# Acuuracy of  100.0 for Model:: DecisionTreeClassifier() found in Random state: 20
# Acuuracy of  100.0 for Model:: KNeighborsClassifier() found in Random state: 20

# %% [markdown]
# We can observe accuracy is same for all the models.as all the models has same accuracy,choosing DecisionTreeClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=20)

# %%
dtc=DecisionTreeClassifier()
dtc_score=cross_val_score(dtc,x,y,cv=10,scoring='accuracy')
print("decision tree    cross validation score:",np.mean(dtc_score))
# Out:
# decision tree    cross validation score: 1.0

# %%
dtc.fit(x_train,y_train)
predicted_dtc=dtc.predict(x_test)
print("Accuracy score::",accuracy_score(y_test,predicted_dtc))
print("Training accuracy::",dtc.score(x_train,y_train))
print("Test accuracy::",dtc.score(x_test,y_test))
# Out:
# Accuracy score:: 1.0
# Training accuracy:: 1.0
# Test accuracy:: 1.0

# %%
print("Confusion Matrix::",confusion_matrix(y_test,predicted_dtc))
print("Classification Report ::",classification_report(y_test,predicted_dtc))
# Out:
# Confusion Matrix:: [[382   0]
#  [  0  76]]
# Classification Report ::               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       382
#            1       1.00      1.00      1.00        76
#
#     accuracy                           1.00       458
#    macro avg       1.00      1.00      1.00       458
# weighted avg       1.00      1.00      1.00       458

# %% [markdown]
# # Hyper parameter tuning

# %%
parameters = {'max_depth' : range(1,25),
              'criterion' : ('gini', 'entropy'),
               'max_features' : ('auto', 'sqrt', 'log2'),
              'min_samples_split' : (2,4,6),
              'min_samples_leaf': range(1,5)
             }

# %%
from sklearn.model_selection import GridSearchCV

Dt_grid=GridSearchCV(DecisionTreeClassifier(),parameters,cv=12,scoring='accuracy')

# %%
Dt_grid.fit(x_train,y_train)
Dt_grid.best_estimator_
gcv_pred=Dt_grid.best_estimator_.predict(x_test)
print("Accuracy after parameter tuning::",accuracy_score(y_test,gcv_pred))
# Out:
# Accuracy after parameter tuning:: 1.0

# %% [markdown]
# Accuracy is same even after tuning the hyper parameter,saving the model

# %% [markdown]
# # Saving the model

# %%
import joblib

joblib.dump(Dt_grid.best_estimator_,"hr_attrition.obj")
# Out:
# ['hr_attrition.obj']
