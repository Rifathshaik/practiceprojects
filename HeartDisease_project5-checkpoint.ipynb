# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. #3 (age)
# 2. #4 (sex)
# 3. #9 (cp)
# 4. #10 (trestbps)
# 5. #12 (chol)
# 6. #16 (fbs)
# 7. #19 (restecg)
# 8. #32 (thalach)
# 9. #38 (exang)
# 10. #40 (oldpeak)
# 11. #41 (slope)
# 12. #44 (ca)
# 13. #51 (thal)
# 14. #58 (num) (the predicted attribute)

# %%
df=pd.read_csv('heartdisease_data.csv')
df.head()
# Out:
#    63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0  44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1  60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2  55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3  66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4  66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0

# %%
df.columns
# Out:
# Index(['63', '1', '4', '140', '260', '0', '1.1', '112', '1.2', '3', '2', '?',
#        '?.1', '2.1'],
#       dtype='object')

# %%
#renaming column names
df.columns=['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang',
            'oldpeak','slope','ca','thal','num']

# %%
df.head()
# Out:
#    age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0   44    1   4      130  209   0        1     127     0       0     ?  ?
# 1   60    1   4      132  218   0        1     140     1     1.5     3  ?
# 2   55    1   4      142  228   0        1     149     1     2.5     1  ?
# 3   66    1   3      110  213   1        2      99     1     1.3     2  ?
# 4   66    1   3      120    0   0        1     120     0    -0.5     1  ?
#
#   thal  num
# 0    ?    0
# 1    ?    2
# 2    ?    1
# 3    ?    0
# 4    ?    0

# %%
#cheking for size
df.shape
# Out:
# (199, 14)

# %%
#checking for nulls
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       199 non-null    int64
#  1   sex       199 non-null    int64
#  2   cp        199 non-null    int64
#  3   trestbps  199 non-null    object
#  4   chol      199 non-null    object
#  5   fbs       199 non-null    object
#  6   restecg   199 non-null    int64
#  7   thalach   199 non-null    object
#  8   exang     199 non-null    object
#  9   oldpeak   199 non-null    object
#  10  slope     199 non-null    object
#  11  ca        199 non-null    object
#  12  thal      199 non-null    object
#  13  num       199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 21.9+ KB

# %%
df.replace('?',np.NaN,inplace=True)

# %%
df.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps     56
# chol          7
# fbs           7
# restecg       0
# thalach      53
# exang        53
# oldpeak      56
# slope       102
# ca          197
# thal        165
# num           0
# dtype: int64

# %%
#there are only 2 data types.We can observe that there are numerical values stored as object data types.
#converting the numeric values to object types.
#extracting the object type columns
obj_type=df.select_dtypes(include=['object'])
obj_type.columns
# Out:
# Index(['trestbps', 'chol', 'fbs', 'thalach', 'exang', 'oldpeak', 'slope', 'ca',
#        'thal'],
#       dtype='object')

# %%
#as all are of object type,replacing them with most frequent value
for col in obj_type.columns:
        df[col].fillna(df[col].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
#converting object type columns to integer
for col in obj_type.columns:
           df[col]= df[col].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       199 non-null    int64
#  1   sex       199 non-null    int64
#  2   cp        199 non-null    int64
#  3   trestbps  199 non-null    float64
#  4   chol      199 non-null    float64
#  5   fbs       199 non-null    float64
#  6   restecg   199 non-null    int64
#  7   thalach   199 non-null    float64
#  8   exang     199 non-null    float64
#  9   oldpeak   199 non-null    float64
#  10  slope     199 non-null    float64
#  11  ca        199 non-null    float64
#  12  thal      199 non-null    float64
#  13  num       199 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 21.9 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  199.000000  199.000000  199.000000  199.000000  199.000000  199.000000
# mean    59.331658    0.969849    3.502513  129.859296  172.050251    0.341709
# std      7.827080    0.171433    0.796928   19.315308  116.880788    0.475479
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  120.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000  122.000000  214.000000    0.000000
# 75%     64.000000    1.000000    4.000000  140.000000  254.000000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope     ca  \
# count  199.000000  199.000000  199.000000  199.000000  199.000000  199.0
# mean     0.733668  122.105528    0.738693    0.940704    2.065327    0.0
# ...

# %% [markdown]
# outliers present in trestbps,
#                     cholestrol,
#                   thal columns

# %%
l1=['trestbps', 'chol', 'fbs', 'thalach', 'exang', 'oldpeak', 'slope', 'ca',
       'thal']
for i in range(0,9):
        print("No.of unque values in ",l1[i],"::",df[l1[i]].nunique())
        print("\n",l1[i]," \n ",df[l1[i]].value_counts())
        print("===========================================================")
# Out:
# No.of unque values in  trestbps :: 40
#
#  trestbps
#   120.0    72
# 130.0    15
# 110.0     9
# 150.0     9
# 140.0     9
# 160.0     8
# 122.0     6
# 142.0     5
# 126.0     4
# 128.0     4
# 170.0     4
# 124.0     4
# 134.0     4
# 136.0     4
# 144.0     4
# 132.0     3
# 158.0     3
# 180.0     2
# 154.0     2
# 152.0     2
# 116.0     2
# 125.0     2
# 138.0     2
# 155.0     2
# 112.0     2
# 104.0     2
# 114.0     1
# 172.0     1
# 190.0     1
# 100.0     1
# 118.0     1
# 156.0     1
# 102.0     1
# 96.0      1
# 106.0     1
# 135.0     1
# 146.0     1
# 178.0     1
# 0.0       1
# 127.0     1
# Name: trestbps, dtype: int64
# ...
# No.of unque values in  chol :: 99
#
#  chol
#   0.0      56
# 258.0     4
# 220.0     4
# 203.0     4
# 223.0     3
#          ..
# 261.0     1
# 181.0     1
# 260.0     1
# 175.0     1
# 209.0     1
# Name: chol, Length: 99, dtype: int64
# ...
# No.of unque values in  fbs :: 2
#
#  fbs
#   0.0    131
# 1.0     68
# Name: fbs, dtype: int64
# ...

# %%
#there is only one unique valu in ca column,hence dropping it

df.drop(['ca'],axis=1,inplace=True)

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'thal', 'num'],
#       dtype='object')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 3))
sns.distplot(df['age'] , color="dodgerblue", ax=axes[0], axlabel='age')
sns.distplot(df['sex'] , color="deeppink", ax=axes[1], axlabel='sex')
sns.distplot(df['cp'] , color="gold", ax=axes[2], axlabel='cp')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 3))
sns.distplot(df['trestbps'] , color="dodgerblue",ax=axes[0],axlabel='trestbps')
sns.distplot(df['chol'] , color="deeppink",ax=axes[1],axlabel='chol')
sns.distplot(df['fbs'] , color="gold",ax=axes[2],axlabel='fbs')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 3))
sns.distplot(df['restecg'] , color="dodgerblue", ax=axes[0], axlabel='restecg')
sns.distplot(df['thalach'] , color="deeppink", ax=axes[1], axlabel='thalach')
sns.distplot(df['exang'] , color="gold", ax=axes[2], axlabel='exang')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 3))
sns.distplot(df['oldpeak'] , color="dodgerblue", ax=axes[0], axlabel='oldpeak')
sns.distplot(df['slope'] , color="deeppink", ax=axes[1], axlabel='slope')

sns.distplot(df['thal'] , color="dodgerblue",label='thal')

# %%
sns.countplot(df['num'],hue=df['sex'])

# %%
sns.barplot(y=df['age'],x=df['num'],hue=df['sex'])

# %%
sns.pairplot(df)

# %%
#plotting outliers
df.boxplot()

# %% [markdown]
# # Skewness check

# %%
df.skew()
# Out:
# age        -0.397178
# sex        -5.537073
# cp         -1.641267
# trestbps   -0.765472
# chol       -0.461558
# fbs         0.672579
# restecg     0.396540
# thalach     0.258275
# exang      -1.094854
# oldpeak     0.838673
# slope       0.207950
# thal       -5.904837
# num         0.302681
# dtype: float64

# %% [markdown]
# Skewness present in  columns

# %% [markdown]
# # correlation check:

# %%
df_cor=df.corr()

# %%
df_cor
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.033837 -0.039809  0.166609  0.048249  0.137672
# sex       0.033837  1.000000  0.037525 -0.002813 -0.102511 -0.058846
# cp       -0.039809  0.037525  1.000000  0.138156  0.046738 -0.042263
# trestbps  0.166609 -0.002813  0.138156  1.000000  0.124318  0.161990
# chol      0.048249 -0.102511  0.046738  0.124318  1.000000  0.159454
# fbs       0.137672 -0.058846 -0.042263  0.161990  0.159454  1.000000
# restecg   0.001487  0.060305  0.033617  0.076560  0.000925  0.172306
# thalach  -0.149078 -0.003687 -0.107093  0.015914 -0.056706  0.031356
# exang     0.127815  0.028906  0.088211  0.082923  0.113469 -0.174385
# oldpeak   0.131512  0.057243  0.182220  0.248352 -0.067742 -0.133484
# slope     0.107525  0.086842  0.059955  0.099576  0.049629 -0.009947
# thal      0.105902 -0.036085 -0.010080  0.023733 -0.047820 -0.032345
# num       0.286630  0.147190  0.167202  0.148385  0.057064  0.050448
#
# ...

# %% [markdown]
# # Plotting correlation by heatmap

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_cor,cmap='Blues',annot=True)

# %% [markdown]
# Highly correlated columns with target variable:
#
#     1)oldpeak
#
#     2)age
#
#     3)slope
# Highly Negative correlated columns:
#
#     1)thal
#
#     2)thalach
#
#     3)RestECG

# %% [markdown]
# # Removing Outliers:

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
print(z)
# Out:
# [[1.96373685 0.17631813 0.62583065 ... 0.13869083 0.2046578  1.24498245]
#  [0.08560374 0.17631813 0.62583065 ... 1.98434575 0.2046578  0.39575601]
#  [0.5548152  0.17631813 0.62583065 ... 2.26172741 0.2046578  0.42461322]
#  ...
#  [0.5548152  0.17631813 0.62583065 ... 0.13869083 1.49229649 0.39575601]
#  [0.17056384 0.17631813 0.62583065 ... 0.13869083 0.2046578  1.24498245]
#  [0.34177131 0.17631813 1.89013499 ... 0.13869083 0.2046578  0.42461322]]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 11,  23,  32,  50,  65,  69,  71,  75,  78,  95,  96, 125, 127,
#        130, 132, 136, 170, 175, 188, 189, 193, 194, 195], dtype=int64), array([11,  7,  3,  1,  2,  7,  2,  2,  1,  0,  2,  1,  1,  2,  2,  2, 11,
#         3, 11,  1, 11,  1,  2], dtype=int64))

# %%
#removing outliers
df1=df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",df1.shape)
# Out:
# with outliers:: (199, 13)
# After removing outliers:: (176, 13)

# %% [markdown]
# 14% of data removed while treating outliers

# %%
x=df1.drop(['num'],axis=1)

# %%
y=df1['num']

# %%
x.shape
# Out:
# (176, 12)

# %%
y.shape
# Out:
# (176,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (176, 1)

# %%
#removing skewness
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
# Out:
# C:\ANACONDA\lib\site-packages\sklearn\preprocessing\_data.py:3234: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ANACONDA\lib\site-packages\numpy\core\_methods.py:195: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)

# %%
#scaling x
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
#checking best random state
from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

import warnings
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')

# %%
best_Randstate=0
accuracy=0
model=[LogisticRegression(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier(),RandomForestClassifier(),
       AdaBoostClassifier()]
for m in model:
            for i in range(20,200):
                                    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
                                    m.fit(x_train,y_train)
                                    predicted_y=m.predict(x_test)
                                    accu_temp=accuracy_score(y_test,predicted_y)
                                    if(accu_temp>accuracy):
                                                accuracy=accu_temp
                                                best_Randstate=i
            print("Acuuracy of ",accuracy*100,"for Model::",m,"found in Random state:",best_Randstate)
# Out:
# Acuuracy of  52.27272727272727 for Model:: LogisticRegression() found in Random state: 43
# Acuuracy of  52.27272727272727 for Model:: SVC() found in Random state: 43
# Acuuracy of  52.27272727272727 for Model:: DecisionTreeClassifier() found in Random state: 43
# Acuuracy of  52.27272727272727 for Model:: KNeighborsClassifier() found in Random state: 43
# Acuuracy of  54.54545454545454 for Model:: RandomForestClassifier() found in Random state: 113
# Acuuracy of  54.54545454545454 for Model:: AdaBoostClassifier() found in Random state: 113

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=43)

# %%
dtc=DecisionTreeClassifier()
dtc_score=cross_val_score(dtc,x,y,cv=12,scoring='accuracy')
print("score of decision tree  Model through cross validation:",np.mean(dtc_score))
# Out:
# score of decision tree  Model through cross validation: 0.3353174603174603

# %%
dtc.fit(x_train,y_train)
predicted_dtc=dtc.predict(x_test)
print("Accuracy score::",accuracy_score(y_test,predicted_dtc))
print("Training accuracy::",dtc.score(x_train,y_train))
print("Test accuracy::",dtc.score(x_test,y_test))
# Out:
# Accuracy score:: 0.3409090909090909
# Training accuracy:: 1.0
# Test accuracy:: 0.3409090909090909

# %%
knn=KNeighborsClassifier()
knn_score=cross_val_score(knn,x,y,cv=12,scoring='accuracy')
print("score of decision tree  Model through cross validation:",np.mean(knn_score))
# Out:
# score of decision tree  Model through cross validation: 0.3503968253968255

# %%
knn.fit(x_train,y_train)
predicted_knn=knn.predict(x_test)
print("Accuracy score::",accuracy_score(y_test,predicted_knn))
print("Training accuracy::",knn.score(x_train,y_train))
print("Test accuracy::",knn.score(x_test,y_test))
# Out:
# Accuracy score:: 0.3409090909090909
# Training accuracy:: 0.5227272727272727
# Test accuracy:: 0.3409090909090909

# %% [markdown]
# # Using ensemble techniques:

# %%
model=[RandomForestClassifier(),
 AdaBoostClassifier(),
BaggingClassifier(),
 GradientBoostingClassifier()]

for m in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=113)
    m.fit(x_train,y_train)
    predicted_val=m.predict(x_test)
    print("Accuracy score::",accuracy_score(y_test,predicted_val)*100,"for model::",m)
# Out:
# Accuracy score:: 45.45454545454545 for model:: RandomForestClassifier()
# Accuracy score:: 22.727272727272727 for model:: AdaBoostClassifier()
# Accuracy score:: 45.45454545454545 for model:: BaggingClassifier()
# Accuracy score:: 45.45454545454545 for model:: GradientBoostingClassifier()

# %% [markdown]
# # Hyper parameter tuning:

# %% [markdown]
# # RandomForest HYPER PARAMETER TUNING:

# %%
parameters={ 'n_estimators':range(10,100),
              'criterion':('gini', 'entropy'),
            'max_features':('auto', 'sqrt', 'log2')
    
}

# %%
rfc_grid=GridSearchCV(RandomForestClassifier(),parameters,cv=10,scoring='accuracy')

# %%
rfc_grid.fit(x_train,y_train)
rfc_pred=rfc_grid.best_estimator_.predict(x_test)
print("Accuracy after parameter tuning::",accuracy_score(y_test,rfc_pred))
# Out:
# Accuracy after parameter tuning:: 0.4772727272727273

# %%
print("Confusion Matrix:",confusion_matrix(y_test,rfc_pred))
# Out:
# Confusion Matrix: [[4 6 2 0 0]
#  [1 9 2 1 0]
#  [0 2 4 2 0]
#  [1 1 2 3 1]
#  [0 1 1 0 1]]

# %%
print("Classification report:",classification_report(y_test,rfc_pred))
# Out:
# Classification report:               precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44        12
#            1       0.47      0.69      0.56        13
#            2       0.36      0.50      0.42         8
#            3       0.50      0.38      0.43         8
#            4       0.50      0.33      0.40         3
#
#     accuracy                           0.48        44
#    macro avg       0.50      0.45      0.45        44
# weighted avg       0.51      0.48      0.47        44

# %% [markdown]
# # Saving the model:

# %%
import joblib

# %%
joblib.dump(rfc_grid.best_estimator_,"HeartDiseasePrediction.obj")
# Out:
# ['HeartDiseasePrediction.obj']
