# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('agaricus-lepiotadata.csv')

# %%
df.head()
# Out:
#    p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 0  e  x  s  y  t   a  f  c   b  k  ...   s  w   w   p   w  o   p   n   n  g
# 1  e  b  s  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   n  m
# 2  p  x  y  w  t   p  f  c   n  n  ...   s  w   w   p   w  o   p   k   s  u
# 3  e  x  s  g  f   n  f  w   b  k  ...   s  w   w   p   w  o   e   n   a  g
# 4  e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   n  g
#
# [5 rows x 23 columns]

# %% [markdown]
# we can observe column names are missing,adding column names for better understandin

# %%
df.columns=['class','cap-shape','cap-surface','cap-color','bruises','odor','gill-attachment','gill-spacing',
            'gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring',
            'stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring',
            'veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat'
            ]

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     e         x           s         y       t    a               f
# 1     e         b           s         w       t    l               f
# 2     p         x           y         w       t    p               f
# 3     e         x           s         g       f    n               f
# 4     e         x           y         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         b          k  ...                        s
# 1            c         b          n  ...                        s
# 2            c         n          n  ...                        s
# 3            w         b          k  ...                        s
# 4            c         b          n  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8123 entries, 0 to 8122
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8123 non-null   object
#  1   cap-shape                 8123 non-null   object
#  2   cap-surface               8123 non-null   object
#  3   cap-color                 8123 non-null   object
#  4   bruises                   8123 non-null   object
#  5   odor                      8123 non-null   object
#  6   gill-attachment           8123 non-null   object
#  7   gill-spacing              8123 non-null   object
#  8   gill-size                 8123 non-null   object
#  9   gill-color                8123 non-null   object
#  10  stalk-shape               8123 non-null   object
#  11  stalk-root                8123 non-null   object
#  12  stalk-surface-above-ring  8123 non-null   object
# ...

# %% [markdown]
# As all the columns are of object type converting them to numeric through label encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['class']=le.fit_transform(df['class'])
df['cap-shape']=le.fit_transform(df['cap-shape'])
df['cap-surface']=le.fit_transform(df['cap-surface'])
df['cap-color']=le.fit_transform(df['cap-color'])
df['bruises']=le.fit_transform(df['bruises'])
df['odor']=le.fit_transform(df['odor'])

# %%
df['gill-attachment']=le.fit_transform(df['gill-attachment'])
df['gill-spacing']=le.fit_transform(df['gill-spacing'])
df['gill-size']=le.fit_transform(df['gill-size'])
df['gill-color']=le.fit_transform(df['gill-color'])
df['stalk-shape']=le.fit_transform(df['stalk-shape'])
df['stalk-root']=le.fit_transform(df['stalk-root'])

# %%
df['stalk-surface-above-ring']=le.fit_transform(df['stalk-surface-above-ring'])
df['stalk-surface-below-ring']=le.fit_transform(df['stalk-surface-below-ring'])
df['stalk-color-above-ring']=le.fit_transform(df['stalk-color-above-ring'])
df['stalk-color-below-ring']=le.fit_transform(df['stalk-color-below-ring'])
df['veil-type']=le.fit_transform(df['veil-type'])
df['veil-color']=le.fit_transform(df['veil-color'])

# %%
df['ring-number']=le.fit_transform(df['ring-number'])
df['ring-type']=le.fit_transform(df['ring-type'])
df['spore-print-color']=le.fit_transform(df['spore-print-color'])
df['population']=le.fit_transform(df['population'])
df['habitat']=le.fit_transform(df['habitat'])

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      0          5            2          9        1     0                1
# 1      0          0            2          8        1     3                1
# 2      1          5            3          8        1     6                1
# 3      0          5            2          3        0     5                1
# 4      0          5            3          9        1     0                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          0           4  ...                         2
# 1             0          0           5  ...                         2
# 2             0          1           5  ...                         2
# 3             1          0           4  ...                         2
# 4             0          0           5  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [markdown]
# Describing the data frame

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8123.000000  8123.000000  8123.000000  8123.000000  8123.000000
# mean      0.481965     3.347901     1.827650     4.504740     0.415487
# std       0.499705     1.604323     1.229947     2.545972     0.492836
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8123.000000      8123.000000   8123.000000  8123.000000  8123.000000
# mean      4.144528         0.974147      0.161517     0.309122     4.810784
# std       2.103758         0.158705      0.368030     0.462160     3.540565
# ...

# %%
import seaborn as sns
sns.countplot(df['class'])

# %% [markdown]
# # checking for correlation

# %%
df_cor=df.corr()
df_cor
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052826     0.178440  -0.031361
# cap-shape                 0.052826   1.000000    -0.050475  -0.048181
# cap-surface               0.178440  -0.050475     1.000000  -0.019398
# cap-color                -0.031361  -0.048181    -0.019398   1.000000
# bruises                  -0.501758  -0.035530     0.070214  -0.000736
# odor                     -0.093675  -0.022050     0.045220  -0.387119
# gill-attachment           0.129188   0.078850    -0.034183   0.041440
# gill-spacing             -0.348358   0.013253    -0.282302   0.144250
# gill-size                 0.539944   0.053872     0.208103  -0.169452
# gill-color               -0.530574  -0.006010    -0.161014   0.084654
# stalk-shape              -0.101888   0.063949    -0.014104  -0.456562
# stalk-root               -0.379688   0.029973    -0.126300   0.321381
# ...

# %%
df_cor['class'].sort_values(ascending=False)
# Out:
# class                       1.000000
# gill-size                   0.539944
# population                  0.298776
# habitat                     0.216990
# cap-surface                 0.178440
# spore-print-color           0.172063
# veil-color                  0.145133
# gill-attachment             0.129188
# cap-shape                   0.052826
# cap-color                  -0.031361
# odor                       -0.093675
# stalk-shape                -0.101888
# stalk-color-below-ring     -0.146824
# stalk-color-above-ring     -0.154096
# ring-number                -0.214349
# stalk-surface-below-ring   -0.298901
# stalk-surface-above-ring   -0.334712
# gill-spacing               -0.348358
# stalk-root                 -0.379688
# ring-type                  -0.411942
# bruises                    -0.501758
# gill-color                 -0.530574
# veil-type                        NaN
# Name: class, dtype: float64

# %% [markdown]
# # OBSERVATION:

# %% [markdown]
# 1.gill-size,population,habitat -these are the most positively correlated columns
#
#
# 2.ring-type,bruises,gill-color,veil-type-these are the most negatively correlated columns

# %% [markdown]
# plotting correlations

# %%
import seaborn as sns
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_cor,cmap='coolwarm',annot=True)

# %% [markdown]
# We can observe veil-type is not at all correlated to any column,hence dropping it

# %%
df.drop(['veil-type'],axis=1,inplace=True)

# %% [markdown]
# # PLOTTING OUTLIERS

# %%
df.boxplot()

# %%
 sns.boxplot(df['population'],orient="v")

# %%
 sns.boxplot(df['habitat'],orient="v")

# %%
 sns.boxplot(df['gill-attachment'],orient="v")

# %%
 sns.boxplot(df['stalk-color-below-ring'],orient="v")

# %%
 sns.boxplot(df['stalk-color-above-ring'],orient="v")

# %%
 sns.boxplot(df['ring-number'],orient="v")

# %%
 sns.boxplot(df['stalk-surface-below-ring'],orient="v")

# %%
 sns.boxplot(df['stalk-surface-above-ring'],orient="v")

# %%
 sns.boxplot(df['gill-spacing'],orient="v")

# %%
 sns.boxplot(df['stalk-root'],orient="v")

# %%
 sns.boxplot(df['bruises'],orient="v")

# %% [markdown]
# We can obsrve very less columns have outliers

# %% [markdown]
# Checking if data is skewed ornot

# %%
df.skew()
# Out:
# class                       0.072201
# cap-shape                  -0.246839
# cap-surface                -0.590773
# cap-color                   0.706854
# bruises                     0.343051
# odor                       -0.080555
# gill-attachment            -5.976678
# gill-spacing                1.839889
# gill-size                   0.826228
# gill-color                  0.061324
# stalk-shape                -0.271632
# stalk-root                  0.948311
# stalk-surface-above-ring   -1.098553
# stalk-surface-below-ring   -0.757513
# stalk-color-above-ring     -1.835253
# stalk-color-below-ring     -1.791413
# veil-color                 -6.946490
# ring-number                 2.701431
# ring-type                  -0.289803
# spore-print-color           0.548227
# population                 -1.413251
# habitat                     0.985957
# dtype: float64

# %%
sns.pairplot(df)

# %% [markdown]
# Removing outliers

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df))
print(z)

#defining threshold,values above threshold are outliers
threshold = 3
print(np.where(z > 3))


#removing outliers
df2=df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",df2.shape)
# Out:
# [[0.96455727 1.02984283 0.14013674 ... 0.25054462 1.3131121  0.29553654]
#  [0.96455727 2.08692816 0.14013674 ... 0.25054462 1.3131121  0.86756584]
#  [1.03674508 1.02984283 0.95323012 ... 0.67025464 0.51442924 2.03066822]
#  ...
#  [0.96455727 0.84021976 0.14013674 ... 1.50967469 2.11179496 0.28601465]
#  [1.03674508 0.21686556 0.95323012 ... 1.42829549 0.28425362 0.28601465]
#  [0.96455727 1.02984283 0.14013674 ... 0.16916541 2.11179496 0.28601465]]
# (array([1815, 2127, 2127, ..., 8120, 8122, 8122], dtype=int64), array([15, 14, 15, ..., 16,  6, 16], dtype=int64))
# with outliers:: (8123, 22)
# After removing outliers:: (6567, 22)

# %% [markdown]
# MODELLING THE DATA

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
X=df2.iloc[:,1:23]
Y=df2['class']

# %% [markdown]
# Removing skewness of data

# %%
from sklearn.preprocessing import power_transform
X=power_transform(X,method='yeo-johnson')

# %%
X
# Out:
# array([[ 1.01552698,  0.01306659,  1.627254  , ...,  0.04127742,
#         -1.62979021,  0.25821232],
#        [-2.11660242,  0.01306659,  1.378819  , ...,  0.04127742,
#         -1.62979021,  1.16078243],
#        [ 1.01552698,  0.98817281,  1.378819  , ..., -0.60542155,
#         -0.92308477,  1.55358997],
#        ...,
#        [-0.28069358,  0.01306659, -1.06333333, ...,  1.3678683 ,
#          0.10295728, -1.04646844],
#        [-0.28069358,  0.98817281,  0.03929652, ...,  1.3678683 ,
#          0.10295728, -1.04646844],
#        [-0.28069358,  0.98817281,  0.03929652, ...,  1.3678683 ,
#          0.10295728,  0.82602243]])

# %%
X.shape
# Out:
# (6567, 21)

# %%
Y.shape
# Out:
# (6567,)

# %%
Y=Y.values.reshape(-1,1)

# %%
#creating test/train split
#scaling not necessary
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=43)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
predicted_y=lr.predict(x_test)
print("Accuracy score::",accuracy_score(y_test,predicted_y))
print("Training data  score::",lr.score(x_train,y_train))
print("Test data  score::",lr.score(x_test,y_test))
# Out:
# Accuracy score:: 0.9611872146118722
# Training data  score:: 0.9623072529982867
# Test data  score:: 0.9611872146118722

# %% [markdown]
# # ADABOOST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
adb=AdaBoostClassifier()
adb.fit(x_train,y_train)
predicted_adb=adb.predict(x_test)
print("Accuracy score::",accuracy_score(y_test,predicted_adb))
print("training score:",adb.score(x_train,y_train))
print("test score:",adb.score(x_test,y_test))
# Out:
# Accuracy score:: 1.0
# training score: 1.0
# test score: 1.0

# %% [markdown]
# # NAIVE BAYES CLASSIFIER

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
predicted_gnb=gnb.predict(x_test)
print("Accuracy score::",accuracy_score(y_test,predicted_gnb))
print("training score:",gnb.score(x_train,y_train))
print("test score:",gnb.score(x_test,y_test))
# Out:
# Accuracy score:: 0.9124809741248098
# training score: 0.9110984199505044
# test score: 0.9124809741248098

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
predicted_rfc=rfc.predict(x_test)
print("Accuracy score::",accuracy_score(y_test,predicted_rfc))
print("training score:",rfc.score(x_train,y_train))
print("test score:",rfc.score(x_test,y_test))
# Out:
# Accuracy score:: 1.0
# training score: 1.0
# test score: 1.0

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
predicted_dtc=dtc.predict(x_test)
print("Accuracy score::",accuracy_score(y_test,predicted_dtc))
print("training score:",rfc.score(x_train,y_train))
print("test score:",rfc.score(x_test,y_test))
# Out:
# Accuracy score:: 1.0
# training score: 1.0
# test score: 1.0

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'C': [0.001, 0.01, 0.1, 1],
            'penalty':['l2'],
            'solver': ['lbfgs']
    
}

# %%
log_grid=GridSearchCV(LogisticRegression(),parameters,cv=5,scoring='accuracy')

# %%
log_grid.fit(x_train,y_train)
log_pred=log_grid.best_estimator_.predict(x_test)

# %%
print("Accuracy after parameter tuning::",accuracy_score(y_test,log_pred))
# Out:
# Accuracy after parameter tuning:: 0.9627092846270928

# %% [markdown]
# We can see accuracy remains same for logistic regression

# %% [markdown]
# There are no parameters to tune for naive bayes

# %% [markdown]
# selecting logistic regression because adaboost,randomforest,decision tree bcause they show 100 percent accuracy

# %% [markdown]
# # SERIALIZATION

# %%
import joblib

# %%
joblib.dump(log_grid.best_estimator_,"Mushroom_project.pkl")
# Out:
# ['Mushroom_project.pkl']
